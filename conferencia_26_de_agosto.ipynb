# %% [markdown]
# “Aprenda a pensar como un programador con Python” – Allen B. Downey (traducción de Think Python).
#
# “Python para todos” – Raúl González Duque (gratuito en línea).
#
# “Introducción a la programación con Python” – Andrés Marzal & Isabel Gracia.
#
# “Python 3 al descubierto” – Albert Casals.
#
# “Programación en Python paso a paso” – Jesús Conde (basado en sus cursos y material).
#
# Java
#
# “Aprenda Java como si estuviera en primero” – Pablo H. Toledo.
#
# “Java 8 – Manual de programación” – Raúl Zambrano.
#
# “Pensar en Java” – Bruce Eckel.
#
# “Java a tope” – Nacho Cabanes.
#
# “Java: Cómo programar” – Paul Deitel & Harvey Deitel

# %% [markdown]
# ![Imagen de WhatsApp 2025-08-27 a las 08.34.35_9ecf87d9.jpg](data:image/jpeg;base64,...)

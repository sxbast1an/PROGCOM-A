# %% [markdown]
# <a href="https://colab.research.google.com/github/sxbast1an/PROGCOM-A/blob/main/juego_no_es_mi_vecino.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

HTML(r"""
<style>
@import url('https://fonts.googleapis.com/css2?family=Press+Start+2P&display=swap');

body {
    background: linear-gradient(135deg, #0b0c10, #1f2833);
    color: #c5c6c7;
    font-family: 'Press Start 2P', cursive;
    margin: 0;
    height: 100vh;
    overflow: hidden;
    display: flex;
    justify-content: center;
    align-items: center;
}

.game-container {
    width: 560px;
    background: #45a29e;
    border-radius: 25px;
    box-shadow: 0 0 20px #66fcf1;
    padding: 25px;
    text-align: center;
    user-select: none;
}

h1 {
    margin: 0 0 20px 0;
    font-size: 22px;
    color: #0b0c10;
    text-shadow: 2px 2px 5px #000;
}

.story-box {
    background: #0b0c10cc;
    padding: 15px;
    border-radius: 12px;
    margin-bottom: 15px;
    box-shadow: inset 0 0 10px #66fcf1;
    font-size: 12px;
    white-space: pre-wrap;
}

.face {
    width: 280px;
    height: 280px;
    margin: 0 auto 15px auto;
    border-radius: 20px;
    box-shadow: 0 0 25px #000;
    background-color: #1f2833; /* color neutro en lugar de imagen */
    display: flex;
    justify-content: center;
    align-items: center;
    color: #66fcf1;
    font-size: 16px;
}

.dialogue-box {
    background: #0b0c10cc;
    padding: 15px;
    min-height: 80px;
    border-radius: 12px;
    margin: 15px 0;
    font-size: 14px;
}

button {
    width: 100%;
    padding: 14px;
    margin: 8px 0;
    border: none;
    border-radius: 12px;
    font-size: 15px;
    font-weight: bold;
    background: #0b0c10;
    color: #66fcf1;
    cursor: pointer;
    box-shadow: 0 0 10px #66fcf1;
}

button:hover:not(:disabled) {
    background: #45a29e;
    color: #0b0c10;
}

button:disabled {
    background: #222;
    color: #444;
}

#killBtn {
    background: #ff3344;
    box-shadow: 0 0 15px #ff3344;
}

#saveBtn {
    background: #33ff88;
    box-shadow: 0 0 15px #33ff88;
}

#restartButton {
    display: none;
    background: #ffd700;
    box-shadow: 0 0 15px #ffd700;
}

.glitch {
    animation: glitchAnim 0.2s infinite;
}

@keyframes glitchAnim {
    0% { filter: hue-rotate(0deg) brightness(1); }
    20% { filter: hue-rotate(40deg) brightness(1.5); transform: translate(-2px, -2px); }
    40% { filter: hue-rotate(-40deg) brightness(0.8); transform: translate(2px, 2px); }
    60% { transform: translate(-3px, 3px); }
    80% { transform: translate(3px, -3px); }
    100% { filter: hue-rotate(0deg) brightness(1); }
}

</style>

<div class="game-container">
    <h1>ESE NO ES MI VECINO — v2.0</h1>

    <div id="story" class="story-box"></div>

    <div id="face" class="face">?</div>

    <div id="dialogue" class="dialogue-box">Haz preguntas…</div>

    <button id="btnName">¿Cómo te llamas?</button>
    <button id="btnPet">¿Tienes mascota?</button>
    <button id="btnFood">¿Qué te gusta comer?</button>
    <button id="btnStreet">¿En qué calle vives?</button>
    <button id="btnJob">¿En qué trabajas?</button>

    <button id="killBtn">⚠ MATAR</button>
    <button id="saveBtn">✔ DEJAR VIVIR</button>

    <button id="restartButton">JUGAR OTRA VEZ</button>
</div>

<script>
const humans = [
    {
        name: "Carlos",
        story: `Nombre: Carlos
Mascota: Gato "Bimbo"
Comida favorita: Empanadas
Calle: Olmo 34
Trabajo: Mantenimiento del edificio`,
        answers: {
            name: "Me llamo Carlos… creo que ya me conoces.",
            pet: "Tengo a mi gato Bimbo.",
            food: "Me encantan las empanadas.",
            street: "Vivo en la calle Olmo 34.",
            job: "Trabajo arreglando cosas del edificio."
        }
    },
    {
        name: "Lucía",
        story: `Nombre: Lucía
Mascota: Perro "Max"
Comida favorita: Pasta
Calle: Luna 12
Trabajo: Librería del barrio`,
        answers: {
            name: "Soy Lucía, la de al lado.",
            pet: "Mi perro Max es muy tranquilo.",
            food: "Me encanta la pasta casera.",
            street: "Vivo en la avenida Luna 12.",
            job: "Trabajo en la librería de la esquina."
        }
    },
    {
        name: "Eduardo",
        story: `Nombre: Eduardo
Mascota: Ninguna
Comida favorita: Hamburguesas
Calle: Sol 88
Trabajo: Programador`,
        answers: {
            name: "Soy Eduardo.",
            pet: "No tengo mascotas.",
            food: "Hamburguesas, siempre hamburguesas.",
            street: "En la calle Sol 88.",
            job: "Soy programador independiente."
        }
    }
];

const monsters = [
    {
        name: "El Devorador",
        answers: {
            name: "Yo soy… humano. Sí.",
            pet: "Tengo mascota… perro-gato-ave.",
            food: "Como… comida humana… sí.",
            street: "Vivo en… calle… humana 3.",
            job: "Trabajo… no comer personas… digo… TRABAJAR."
        }
    },
    {
        name: "La Sombra",
        answers: {
            name: "Me llamo… eh… HUMANO.",
            pet: "Mi mascota es… un monstru–… PERRO.",
            food: "Me gusta comer… calor… energía… humanos… digo, pan.",
            street: "En la calle Oscura, número… humano.",
            job: "Trabajo… acechando… digo… normal."
        }
    }
];

let current;
let isMonster;

const face = document.getElementById("face");
const story = document.getElementById("story");
const dialogue = document.getElementById("dialogue");
const restartButton = document.getElementById("restartButton");

const askButtons = {
    name: document.getElementById("btnName"),
    pet: document.getElementById("btnPet"),
    food: document.getElementById("btnFood"),
    street: document.getElementById("btnStreet"),
    job: document.getElementById("btnJob")
};

document.getElementById("killBtn").onclick = () => decide(true);
document.getElementById("saveBtn").onclick = () => decide(false);
restartButton.onclick = startGame;

function startGame() {
    restartButton.style.display = "none";
    dialogue.textContent = "Haz preguntas…";
    enableButtons(true);

    if (Math.random() < 0.5) {
        current = humans[Math.floor(Math.random() * humans.length)];
        isMonster = false;
        story.textContent = current.story;
    } else {
        current = monsters[Math.floor(Math.random() * monsters.length)];
        isMonster = true;
        story.textContent = "Este vecino no tiene registros oficiales…";
    }

    face.textContent = "?";
}

function enableButtons(state) {
    for (let k in askButtons) askButtons[k].disabled = !state;
}

function ask(type) {
    enableButtons(false);
    dialogue.textContent = "Pensando…";

    setTimeout(() => {
        if (isMonster) face.classList.add("glitch");

        dialogue.textContent = current.answers[type];

        setTimeout(() => {
            face.classList.remove("glitch");
            face.textContent = "?";
            enableButtons(true);
        }, 2000);
    }, 1000);
}

askButtons.name.onclick = () => ask("name");
askButtons.pet.onclick = () => ask("pet");
askButtons.food.onclick = () => ask("food");
askButtons.street.onclick = () => ask("street");
askButtons.job.onclick = () => ask("job");

function decide(kill) {
    enableButtons(false);

    if (kill && isMonster) {
        dialogue.textContent = "✔ Has matado al monstruo. ¡Buena decisión!";
        face.textContent = "👹";
    } else if (kill && !isMonster) {
        dialogue.textContent = "❌ Mataste a un inocente…";
        face.textContent = "☹️";
    } else if (!kill && isMonster) {
        dialogue.textContent = "❌ Dejaste vivir a un monstruo. Ahora es libre…";
        face.textContent = "👹";
    } else {
        dialogue.textContent = "✔ Buen trabajo. Era un humano.";
        face.textContent = "🙂";
    }

    restartButton.style.display = "block";
}

startGame();
</script>
""")
# Out:
#
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Press+Start+2P&display=swap');
#
# body {
#     background: linear-gradient(135deg, #0b0c10, #1f2833);
#     color: #c5c6c7;
#     font-family: 'Press Start 2P', cursive;
#     margin: 0;
#     height: 100vh;
#     overflow: hidden;
#     display: flex;
#     justify-content: center;
#     align-items: center;
# }
#
# .game-container {
#     width: 560px;
#     background: #45a29e;
#     border-radius: 25px;
#     box-shadow: 0 0 20px #66fcf1;
#     padding: 25px;
#     text-align: center;
#     user-select: none;
# }
#
# h1 {
#     margin: 0 0 20px 0;
#     font-size: 22px;
#     color: #0b0c10;
#     text-shadow: 2px 2px 5px #000;
# }
#
# .story-box {
#     background: #0b0c10cc;
#     padding: 15px;
#     border-radius: 12px;
#     margin-bottom: 15px;
#     box-shadow: inset 0 0 10px #66fcf1;
#     font-size: 12px;
#     white-space: pre-wrap;
# }
#
# .face {
#     width: 280px;
#     height: 280px;
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/sxbast1an/PROGCOM-A/blob/main/clase8_poo_programacio_orientada_a_objetos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#floristeria
#1. conjunto de flores, se elige aleatoriamente una cantidad
import random

flores=["tulipan", "lirio", "rosa", "dahlia", "margarita", "girasol", "clavel", "geranio"]
seleccion=random.sample(flores,3)
seleccion
# Out:
# ['girasol', 'margarita', 'dahlia']

# %%
def inventario():
  flores=["tulipan", "lirio", "rosa", "dahlia", "margarita", "girasol", "clavel", "geranio"]
  seleccion=random.sample(flores,3)

  inventario={
      flor:{
          "precio":random.randint(2000,6000),
          "cantidad":random.randint(10,50),
          "vendidas":0
      } for flor in seleccion
      }
  return inventario

# %%
inventario()
# Out:
# {'clavel': {'precio': 5054, 'cantidad': 12, 'vendidas': 0},
#  'margarita': {'precio': 5183, 'cantidad': 29, 'vendidas': 0},
#  'girasol': {'precio': 3422, 'cantidad': 14, 'vendidas': 0}}

# %%
flor=inventario()
flor.items()
# Out:
# dict_items([('margarita', {'precio': 2105, 'cantidad': 26, 'vendidas': 0}), ('dahlia', {'precio': 4185, 'cantidad': 48, 'vendidas': 0}), ('girasol', {'precio': 3567, 'cantidad': 39, 'vendidas': 0})])

# %%
def menu(inventario):
    print("\n---menu de flore disponible carlitos---")
    for flor,datos in inventario.items():
        print(f"{flor}: ${datos['precio']} cant:{datos['cantidad']}disponibles")
    print("-----------------------------------------------------")

# %%
menu(inventario())
# Out:
# ---menu de flore disponible carlitos---
# girasol: $2735 cant:49disponibles
# lirio: $3415 cant:33disponibles
# dahlia: $4392 cant:43disponibles
# -----------------------------------------------------

# %%
def ventas(inventario,flor,cantidad,total_ganado):
  if flor not in inventario:
    print(f"{flor} no se encuentra a la venta😪")
    return total_ganado
  datos=inventario[flor]
  if cantidad>datos["cantidad"]:
    print(f"lo siento. No tenemos la cantidad requerida")
    return total_ganado

    #Realizando la venta
    datos["cantidad"]-=cantidad
    datos["vendidas"]+=cantidad
    venta = datos["precio"] * cantidad
    total_ganado+=venta
    print(f"vendidas: {cantidad} de {flor} por un total de ${venta}")

    #si se acaba, eliminamos la flor
    if datos["contidad"]==0:
      print(f"{flor} ha sido eliminada del inventario 🥀")
      del inventario[flor]
    return total_ganado

# %%
def cerrar_tienda(inventario_inicial,inventario_final,total_ganado):
  print("\n---tienda cerrada---")
  #cambiar el inventario inicial con el final para saber cuantas se vendieron
  flores_vendidas={}
  for flor,datos in inventario_inicial.items():
    cantidad_final=inventario_final.get(flor,{"cantidad":0})["cantidad"]
    vendidas=datos["cantidad"]-cantidad_final
    flores_vendidas[flor]=vendidas

    #Determinar cuales fueron las mas vendidas
    mas_vendidas=max(flores_vendidas,key=flores_vendidas.get)
    menos_vandidas=min(flores_vendidas,key=flores_vendidas.get)


    print(f"la flor mas vendida fue{mas_vendidas}:{flores_vendidas[mas_vendidas]}unidad(es)")
    print(f"la flor menos vendidas fue{menos_vendidas}:{flores_vendidas[flores_vendidas]} unidad(es)")

# %%
flor
# Out:
# {'margarita': {'precio': 2105, 'cantidad': 26, 'vendidas': 0},
#  'dahlia': {'precio': 4185, 'cantidad': 48, 'vendidas': 0},
#  'girasol': {'precio': 3567, 'cantidad': 39, 'vendidas': 0}}

# %%
total_ganado=0
total_ganado=ventas(flor,"rosa", 10,total_ganado)
total_ganado=ventas(flor,"dahila", 18,total_ganado)
total_ganado=ventas(flor,"girasol", 80,total_ganado)
# Out:
# rosa no se encuentra a la venta😪
# dahila no se encuentra a la venta😪
# lo siento. No tenemos la cantidad requerida

# %%
menu(flor)
# Out:
# ---menu de flore disponible carlitos---
# margarita: $2105 cant:26disponibles
# dahlia: $4185 cant:48disponibles
# girasol: $3567 cant:39disponibles
# -----------------------------------------------------

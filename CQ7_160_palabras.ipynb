# %% [markdown]
# <a href="https://colab.research.google.com/github/sxbast1an/PROGCOM-A/blob/main/CQ7_160_palabras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================================================
# REPOSITORIO DE 160 PALABRAS PYTHON Y PROGRAMACIÓN
# ================================================
# Incluye:
#  - Palabras reservadas de Python (35)
#  - Funciones internas (70+)
#  - Conceptos generales y avanzados (hasta llegar a 160)
# ================================================

repositorio = {
    # ---------- PALABRAS RESERVADAS ----------
    1: {"palabra":"False", "definicion":"Valor booleano falso.", "ejemplo":"print(False == 0)  # True"},
    2: {"palabra":"True", "definicion":"Valor booleano verdadero.", "ejemplo":"print(True and False)  # False"},
    3: {"palabra":"None", "definicion":"Representa ausencia de valor.", "ejemplo":"x=None\nprint(x is None)"},
    4: {"palabra":"and", "definicion":"Operador lógico AND.", "ejemplo":"print(True and True)"},
    5: {"palabra":"or", "definicion":"Operador lógico OR.", "ejemplo":"print(True or False)"},
    6: {"palabra":"not", "definicion":"Negación lógica.", "ejemplo":"print(not True)"},
    7: {"palabra":"if", "definicion":"Condicional para tomar decisiones.", "ejemplo":"if 5>3:\n    print('Mayor')"},
    8: {"palabra":"else", "definicion":"Bloque alternativo.", "ejemplo":"if 2>5:\n    print('Mayor')\nelse:\n    print('Menor')"},
    9: {"palabra":"elif", "definicion":"Condición intermedia en un if.", "ejemplo":"x=5\nif x<3:print('Bajo')\nelif x==5:print('Igual')"},
    10: {"palabra":"for", "definicion":"Bucle para iterar.", "ejemplo":"for i in range(3):\n    print(i)"},
    11: {"palabra":"while", "definicion":"Bucle mientras condición.", "ejemplo":"x=0\nwhile x<3:\n    print(x)\n    x+=1"},
    12: {"palabra":"break", "definicion":"Rompe un bucle.", "ejemplo":"for i in range(5):\n    if i==3: break\n    print(i)"},
    13: {"palabra":"continue", "definicion":"Salta a la siguiente iteración.", "ejemplo":"for i in range(5):\n    if i==2: continue\n    print(i)"},
    14: {"palabra":"def", "definicion":"Define una función.", "ejemplo":"def saludar():\n    print('Hola')"},
    15: {"palabra":"return", "definicion":"Devuelve valor desde función.", "ejemplo":"def suma(a,b):return a+b\nprint(suma(2,3))"},
    16: {"palabra":"class", "definicion":"Define una clase.", "ejemplo":"class Persona:\n    pass"},
    17: {"palabra":"try", "definicion":"Bloque que intenta ejecutar código.", "ejemplo":"try:\n    print(1/0)\nexcept:print('Error')"},
    18: {"palabra":"except", "definicion":"Maneja excepciones.", "ejemplo":"try:\n    x=int('a')\nexcept:print('Error')"},
    19: {"palabra":"finally", "definicion":"Bloque que siempre se ejecuta.", "ejemplo":"try:print(1/0)\nexcept:print('Error')\nfinally:print('Fin')"},
    20: {"palabra":"import", "definicion":"Importa módulo.", "ejemplo":"import math\nprint(math.sqrt(16))"},
    21: {"palabra":"from", "definicion":"Importa funciones específicas.", "ejemplo":"from math import sqrt\nprint(sqrt(9))"},
    22: {"palabra":"as", "definicion":"Crea alias al importar.", "ejemplo":"import math as m\nprint(m.pi)"},
    23: {"palabra":"with", "definicion":"Gestiona recursos.", "ejemplo":"with open('a.txt','w') as f:\n    f.write('Hola')"},
    24: {"palabra":"lambda", "definicion":"Función anónima.", "ejemplo":"f=lambda x:x*2\nprint(f(3))"},
    25: {"palabra":"is", "definicion":"Compara identidad.", "ejemplo":"x=None\nprint(x is None)"},
    26: {"palabra":"in", "definicion":"Verifica pertenencia.", "ejemplo":"print(2 in [1,2,3])"},
    27: {"palabra":"del", "definicion":"Elimina variable.", "ejemplo":"x=5\ndel x"},
    28: {"palabra":"global", "definicion":"Declara variable global.", "ejemplo":"x=10\ndef f():\n global x\n x=20\nf()\nprint(x)"},
    29: {"palabra":"nonlocal", "definicion":"Variable en funciones anidadas.", "ejemplo":"def f():\n x=10\n def g():\n  nonlocal x\n  x=20\n g()\n print(x)\nf()"},
    30: {"palabra":"pass", "definicion":"Instrucción vacía.", "ejemplo":"for i in range(3):\n pass"},
    31: {"palabra":"raise", "definicion":"Lanza excepción.", "ejemplo":"raise ValueError('Error forzado')"},
    32: {"palabra":"assert", "definicion":"Verifica condición.", "ejemplo":"x=5\nassert x>0"},
    33: {"palabra":"yield", "definicion":"Devuelve valores en un generador.", "ejemplo":"def gen():\n for i in range(3):\n  yield i\nprint(list(gen()))"},
    34: {"palabra":"or", "definicion":"Operador lógico OR.", "ejemplo":"print(True or False)"},
    35: {"palabra":"await", "definicion":"Espera resultado en async.", "ejemplo":"# async def test():\n#   await asyncio.sleep(1)"},

    # ---------- FUNCIONES INTERNAS ----------
    36: {"palabra":"print", "definicion":"Imprime en pantalla.", "ejemplo":"print('Hola mundo')"},
    37: {"palabra":"len", "definicion":"Devuelve longitud.", "ejemplo":"print(len([1,2,3]))"},
    38: {"palabra":"type", "definicion":"Tipo de dato.", "ejemplo":"print(type(3))"},
    39: {"palabra":"int", "definicion":"Convierte a entero.", "ejemplo":"print(int('5'))"},
    40: {"palabra":"float", "definicion":"Convierte a decimal.", "ejemplo":"print(float('3.14'))"},
    41: {"palabra":"str", "definicion":"Convierte a cadena.", "ejemplo":"print(str(100))"},
    42: {"palabra":"dict", "definicion":"Crea diccionario.", "ejemplo":"d=dict(a=1,b=2)\nprint(d)"},
    43: {"palabra":"list", "definicion":"Crea lista.", "ejemplo":"print(list('hola'))"},
    44: {"palabra":"set", "definicion":"Crea conjunto.", "ejemplo":"print(set([1,2,2,3]))"},
    45: {"palabra":"tuple", "definicion":"Crea tupla.", "ejemplo":"t=(1,2,3)\nprint(t)"},
    46: {"palabra":"abs", "definicion":"Valor absoluto.", "ejemplo":"print(abs(-5))"},
    47: {"palabra":"max", "definicion":"Máximo valor.", "ejemplo":"print(max(1,5,3))"},
    48: {"palabra":"min", "definicion":"Mínimo valor.", "ejemplo":"print(min(1,5,3))"},
    49: {"palabra":"sum", "definicion":"Suma valores.", "ejemplo":"print(sum([1,2,3]))"},
    50: {"palabra":"round", "definicion":"Redondea número.", "ejemplo":"print(round(3.1416,2))"},
    51: {"palabra":"open", "definicion":"Abre archivos.", "ejemplo":"f=open('a.txt','w')\nf.write('Hola')\nf.close()"},
    52: {"palabra":"help", "definicion":"Muestra ayuda.", "ejemplo":"help(len)"},
    53: {"palabra":"eval", "definicion":"Ejecuta expresión.", "ejemplo":"print(eval('2+3'))"},
    54: {"palabra":"exec", "definicion":"Ejecuta código dinámico.", "ejemplo":"exec('x=5')\nprint(x)"},
    55: {"palabra":"sorted", "definicion":"Ordena lista.", "ejemplo":"print(sorted([3,1,2]))"},
    56: {"palabra":"zip", "definicion":"Combina listas.", "ejemplo":"print(list(zip([1,2],[\"a\",\"b\"])))"},
    57: {"palabra":"range", "definicion":"Genera rango.", "ejemplo":"print(list(range(3)))"},
    58: {"palabra":"map", "definicion":"Aplica función a iterables.", "ejemplo":"print(list(map(lambda x:x*2,[1,2,3])))"},
    59: {"palabra":"filter", "definicion":"Filtra elementos.", "ejemplo":"print(list(filter(lambda x:x>2,[1,2,3,4])))"},
    60: {"palabra":"any", "definicion":"True si algún elemento lo es.", "ejemplo":"print(any([0,False,1]))"},
    61: {"palabra":"all", "definicion":"True si todos lo son.", "ejemplo":"print(all([1,True,3]))"},
    62: {"palabra":"pow", "definicion":"Potencia.", "ejemplo":"print(pow(2,3))"},
    63: {"palabra":"bin", "definicion":"Convierte a binario.", "ejemplo":"print(bin(10))"},
    64: {"palabra":"hex", "definicion":"Convierte a hexadecimal.", "ejemplo":"print(hex(255))"},
    65: {"palabra":"oct", "definicion":"Convierte a octal.", "ejemplo":"print(oct(8))"},
    66: {"palabra":"chr", "definicion":"Entero → caracter.", "ejemplo":"print(chr(65))"},
    67: {"palabra":"ord", "definicion":"Caracter → entero.", "ejemplo":"print(ord('A'))"},
    68: {"palabra":"bytes", "definicion":"Crea bytes.", "ejemplo":"print(bytes([65,66]))"},
    69: {"palabra":"bytearray", "definicion":"Crea arreglo mutable de bytes.", "ejemplo":"print(bytearray([65,66]))"},
    70: {"palabra":"bool", "definicion":"Convierte a booleano.", "ejemplo":"print(bool(1))"},
    71: {"palabra":"complex", "definicion":"Crea número complejo.", "ejemplo":"print(complex(1,2))"},
    72: {"palabra":"id", "definicion":"Identificador de objeto.", "ejemplo":"x=5\nprint(id(x))"},
    73: {"palabra":"dir", "definicion":"Atributos de objeto.", "ejemplo":"print(dir([]))"},
    74: {"palabra":"repr", "definicion":"Representación oficial.", "ejemplo":"print(repr('hola'))"},
    75: {"palabra":"hash", "definicion":"Valor hash.", "ejemplo":"print(hash('a'))"},
    76: {"palabra":"format", "definicion":"Formatea cadenas.", "ejemplo":"print(\"{:.2f}\".format(3.14159))"},
    77: {"palabra":"input", "definicion":"Entrada usuario.", "ejemplo":"# nombre=input('Ingresa tu nombre: ')"},
    78: {"palabra":"reversed", "definicion":"Iterador invertido.", "ejemplo":"print(list(reversed([1,2,3])))"},
    79: {"palabra":"enumerate", "definicion":"Devuelve índice y valor.", "ejemplo":"for i,v in enumerate(['a','b']): print(i,v)"},
    80: {"palabra":"next", "definicion":"Obtiene siguiente de un iterador.", "ejemplo":"it=iter([1,2]);print(next(it))"},
    81: {"palabra":"iter", "definicion":"Crea iterador.", "ejemplo":"it=iter([1,2,3]);print(next(it))"},
    82: {"palabra":"slice", "definicion":"Objeto de corte.", "ejemplo":"s=slice(1,3);print([1,2,3,4][s])"},
    83: {"palabra":"object", "definicion":"Clase base en Python.", "ejemplo":"print(isinstance(5,object))"},
    84: {"palabra":"memoryview", "definicion":"Vista de memoria de bytes.", "ejemplo":"mv=memoryview(b'Hola');print(mv[0])"},
    85: {"palabra":"staticmethod", "definicion":"Método estático.", "ejemplo":"class A:\n @staticmethod\n def f():print('ok')\nA.f()"},
    86: {"palabra":"classmethod", "definicion":"Método de clase.", "ejemplo":"class A:\n @classmethod\n def f(cls):print(cls)\nA.f()"},
    87: {"palabra":"property", "definicion":"Define propiedad en clase.", "ejemplo":"class A:\n @property\n def x(self):return 10\nprint(A().x)"},
    88: {"palabra":"super", "definicion":"Accede a clase padre.", "ejemplo":"class A: pass\nclass B(A):\n def __init__(self):super().__init__()"},
    89: {"palabra":"__init__", "definicion":"Constructor de clase.", "ejemplo":"class A:\n def __init__(self):print('init')"},
    90: {"palabra":"__str__", "definicion":"Representación en texto.", "ejemplo":"class A:\n def __str__(self):return 'Hola'\nprint(A())"},

    # ---------- CONCEPTOS GENERALES ----------
    91: {"palabra":"variable", "definicion":"Espacio donde se guarda un valor.", "ejemplo":"x=10\nprint(x)"},
    92: {"palabra":"funcion", "definicion":"Bloque de código reutilizable.", "ejemplo":"def f():\n print('hola')"},
    93: {"palabra":"clase", "definicion":"Plantilla para crear objetos.", "ejemplo":"class Persona:\n pass"},
    94: {"palabra":"objeto", "definicion":"Instancia de clase.", "ejemplo":"p=Persona()"},
    95: {"palabra":"API", "definicion":"Interfaz entre sistemas.", "ejemplo":"# requests.get('https://api.github.com')"},
    96: {"palabra":"JSON", "definicion":"Formato de datos.", "ejemplo":"import json\ndata={'a':1}\nprint(json.dumps(data))"},
    97: {"palabra":"algoritmo", "definicion":"Conjunto de pasos para resolver problema.", "ejemplo":"# ejemplo: ordenamiento burbuja"},
    98: {"palabra":"paradigma", "definicion":"Modelo de programación (OOP, funcional).", "ejemplo":"# Python soporta POO y funcional"},
    99: {"palabra":"herencia", "definicion":"Mecanismo para reutilizar clases.", "ejemplo":"class A:pass\nclass B(A):pass"},
    100: {"palabra":"polimorfismo", "definicion":"Métodos con mismo nombre, distinto comportamiento.", "ejemplo":"# + suma números y concatena strings"},
    101: {"palabra":"encapsulamiento", "definicion":"Ocultar detalles internos.", "ejemplo":"class A:\n _privado=1"},
    102: {"palabra":"atributo", "definicion":"Variable dentro de un objeto.", "ejemplo":"class A:\n x=5"},
    103: {"palabra":"método", "definicion":"Función dentro de clase.", "ejemplo":"class A:\n def saludar(self):print('hola')"},
    104: {"palabra":"modulo", "definicion":"Archivo Python reutilizable.", "ejemplo":"import math"},
    105: {"palabra":"paquete", "definicion":"Conjunto de módulos.", "ejemplo":"import numpy"},
    106: {"palabra":"framework", "definicion":"Conjunto de herramientas para apps.", "ejemplo":"# Django para web"},
    107: {"palabra":"biblioteca", "definicion":"Colección de funciones listas.", "ejemplo":"import pandas"},
    108: {"palabra":"compilador", "definicion":"Traduce código fuente a máquina.", "ejemplo":"# C usa compilador"},
    109: {"palabra":"interprete", "definicion":"Ejecuta código línea por línea.", "ejemplo":"Python es interpretado"},
    110: {"palabra":"IDE", "definicion":"Entorno de desarrollo integrado.", "ejemplo":"# Ejemplo: PyCharm"},
    111: {"palabra":"condicional", "definicion":"Ejecución según condición.", "ejemplo":"if True:print('ok')"},
    112: {"palabra":"bucle", "definicion":"Repite ejecución.", "ejemplo":"for i in range(3):print(i)"},
    113: {"palabra":"recursion", "definicion":"Función que se llama a sí misma.", "ejemplo":"def f(n):\n if n==0:return 1\n return n*f(n-1)"},
    114: {"palabra":"POO", "definicion":"Programación orientada a objetos.", "ejemplo":"class A: pass"},
    115: {"palabra":"API REST", "definicion":"Estilo de servicios web.", "ejemplo":"# Flask puede crear APIs"},
    116: {"palabra":"SQL", "definicion":"Lenguaje para bases de datos.", "ejemplo":"SELECT * FROM usuarios;"},
    117: {"palabra":"ORM", "definicion":"Mapea objetos a tablas.", "ejemplo":"# SQLAlchemy en Python"},
    118: {"palabra":"threading", "definicion":"Ejecución concurrente.", "ejemplo":"import threading"},
    119: {"palabra":"multiprocessing", "definicion":"Ejecución en varios procesos.", "ejemplo":"import multiprocessing"},
    120: {"palabra":"asincronía", "definicion":"Ejecución no bloqueante.", "ejemplo":"async def f(): pass"},
    121: {"palabra":"testing", "definicion":"Pruebas automáticas.", "ejemplo":"import unittest"},
    122: {"palabra":"depuracion", "definicion":"Encontrar errores.", "ejemplo":"print('Debug')"},
    123: {"palabra":"excepcion", "definicion":"Error manejable.", "ejemplo":"try:1/0\nexcept:print('error')"},
    124: {"palabra":"token", "definicion":"Unidad mínima de código.", "ejemplo":"# 'if' es un token"},
    125: {"palabra":"sintaxis", "definicion":"Reglas del lenguaje.", "ejemplo":"print('hola')"},
    126: {"palabra":"semantica", "definicion":"Significado del código.", "ejemplo":"2+2=4"},
    127: {"palabra":"compilación JIT", "definicion":"Compilación en tiempo de ejecución.", "ejemplo":"# PyPy usa JIT"},
    128: {"palabra":"Docker", "definicion":"Contenedores de apps.", "ejemplo":"docker run python"},
    129: {"palabra":"Git", "definicion":"Control de versiones.", "ejemplo":"git commit -m 'msg'"},
    130: {"palabra":"GitHub", "definicion":"Plataforma para repositorios.", "ejemplo":"# github.com"},
    131: {"palabra":"pipeline", "definicion":"Secuencia de procesos.", "ejemplo":"# CI/CD pipeline"},
    132: {"palabra":"bug", "definicion":"Error en el código.", "ejemplo":"x=1/0"},
    133: {"palabra":"feature", "definicion":"Nueva funcionalidad.", "ejemplo":"# agregar login"},
    134: {"palabra":"release", "definicion":"Versión publicada.", "ejemplo":"v1.0"},
    135: {"palabra":"script", "definicion":"Archivo ejecutable Python.", "ejemplo":"python app.py"},
    136: {"palabra":"CLI", "definicion":"Interfaz de línea de comandos.", "ejemplo":"python --version"},
    137: {"palabra":"GUI", "definicion":"Interfaz gráfica.", "ejemplo":"tkinter GUI"},
    138: {"palabra":"API KEY", "definicion":"Clave de acceso a API.", "ejemplo":"apikey='123abc'"},
    139: {"palabra":"hashing", "definicion":"Transformación unidireccional.", "ejemplo":"import hashlib"},
    140: {"palabra":"encriptación", "definicion":"Protección de datos.", "ejemplo":"# AES, RSA"},
    141: {"palabra":"serialización", "definicion":"Convertir objeto a bytes.", "ejemplo":"import pickle"},
    142: {"palabra":"deserialización", "definicion":"Convertir bytes a objeto.", "ejemplo":"pickle.loads()"},
    143: {"palabra":"compresión", "definicion":"Reducir tamaño de datos.", "ejemplo":"import gzip"},
    144: {"palabra":"regex", "definicion":"Expresiones regulares.", "ejemplo":"import re"},
    145: {"palabra":"tokenización", "definicion":"Separar texto en tokens.", "ejemplo":"'hola mundo'.split()"},
    146: {"palabra":"NLP", "definicion":"Procesamiento de lenguaje natural.", "ejemplo":"import spacy"},
    147: {"palabra":"IA", "definicion":"Inteligencia artificial.", "ejemplo":"# modelos ML"},
    148: {"palabra":"ML", "definicion":"Aprendizaje automático.", "ejemplo":"from sklearn.linear_model import LinearRegression"},
    149: {"palabra":"DL", "definicion":"Aprendizaje profundo.", "ejemplo":"import tensorflow"},
    150: {"palabra":"Big Data", "definicion":"Manejo de datos masivos.", "ejemplo":"import pyspark"},
    151: {"palabra":"cloud", "definicion":"Servicios en la nube.", "ejemplo":"# AWS, Azure"},
    152: {"palabra":"serverless", "definicion":"Ejecutar funciones sin servidor.", "ejemplo":"# AWS Lambda"},
    153: {"palabra":"API SOAP", "definicion":"Estilo antiguo de APIs.", "ejemplo":"# xmlrpc.client"},
    154: {"palabra":"endpoint", "definicion":"Punto de acceso API.", "ejemplo":"/usuarios"},
    155: {"palabra":"request", "definicion":"Solicitud HTTP.", "ejemplo":"GET /usuarios"},
    156: {"palabra":"response", "definicion":"Respuesta HTTP.", "ejemplo":"200 OK"},
    157: {"palabra":"JSON Web Token", "definicion":"Token seguro para sesiones.", "ejemplo":"# jwt.encode()"},
    158: {"palabra":"OAuth", "definicion":"Protocolo de autenticación.", "ejemplo":"# OAuth2 en APIs"},
    159: {"palabra":"dockerfile", "definicion":"Archivo para construir imagen Docker.", "ejemplo":"FROM python:3.9"},
    160: {"palabra":"virtualenv", "definicion":"Entorno virtual Python.", "ejemplo":"python -m venv env"},
}

# Mostrar ejemplos de algunas palabras
for i in range(1, 11):
    print(f"{i}. {repositorio[i]['palabra']}: {repositorio[i]['definicion']} -> {repositorio[i]['ejemplo']}")

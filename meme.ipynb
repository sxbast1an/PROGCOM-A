# %% [markdown]
# <a href="https://colab.research.google.com/github/sxbast1an/PROGCOM-A/blob/main/meme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![7f2eeac26d68474f02ef41b17969816b.jpg](data:image/jpeg;base64,...)

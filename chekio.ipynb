# %% [markdown]
# <a href="https://colab.research.google.com/github/sxbast1an/PROGCOM-A/blob/main/chekio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
chekio

# %% [markdown]
# ![image.png](data:image/png;base64,...)
